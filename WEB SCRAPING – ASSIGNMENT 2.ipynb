# %% [markdown]
# # WEB SCRAPING – ASSIGNMENT 2

# %%
# Installing selenium

# !pip install selenium

# Importing all required libraries for this assignment
import pandas as pd
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings("ignore")
import time

# %% [markdown]
# # Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
# Connecting to webdriver (need to enter chromedriver.exe manually)

driver = webdriver.Chrome(r'C:\FLIP ROBO\Crome Driver\chromedriver.exe')

# Getting URL

url = 'https://www.naukri.com/'
driver.get(url)

# %%
# Maximizing the window

driver.maximize_window()

# %%
# inserting required fileds for the result

search_job = driver.find_element(By.CLASS_NAME , "suggestor-input")

search_job.send_keys("Data Analyst")

search_loc = driver.find_element (By.XPATH, '/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')

search_loc.send_keys ('Bangalore')

search_button = driver.find_element (By.CLASS_NAME, "qsbSubmit")

search_button.click()

# %%
# Getting all details of columns sorted.

job_title = []

title_tag = driver.find_elements(By.XPATH, '//a[@class="title fw500 ellipsis"]')
for i in title_tag[0:10]:
    job_title.append(i.text)

job_location = []

title_tag = driver.find_elements (By.XPATH, '//span[@class="ellipsis fleft fs12 lh16 locWdth"]')
for i in title_tag[0:10]:
    job_location.append(i.text)

company_name = []

title_tag = driver.find_elements (By.XPATH, '//a[@class="subTitle ellipsis fleft"]')
for i in title_tag[0:10]:
    company_name.append(i.text)

experience = []

title_tag = driver.find_elements (By.XPATH, '//span[@class="ellipsis fleft fs12 lh16 expwdth"]')
for i in title_tag[0:10]:
    experience.append(i.text)

# %%
# checking lengt of each column

print (len(job_title), len (job_location), len (company_name), len (experience))
# Out:
# 10 10 10 10

# %%
# Creating DataFrame with available information

df = pd.DataFrame ({'Job Title': job_title, 'Job Location': job_location, 'Company Name': company_name, 'Experience': experience})
df
# Out:
#                                            Job Title         Job Location  \
# 0                                       Data Analyst  Bangalore/Bengaluru
# 1  APRP Manager / Senior Data Analyst - MeritTrac...  Bangalore/Bengaluru
# 2                                    Sr Data Analyst  Bangalore/Bengaluru
# 3                     Senior Data Management Analyst  Bangalore/Bengaluru
# 4           Senior Data Analyst - PLM Data Migration  Bangalore/Bengaluru
# 5                                People Data Analyst  Bangalore/Bengaluru
# 6       Associate Healthcare Research & Data Analyst  Bangalore/Bengaluru
# 7                                  Lead Data Analyst  Bangalore/Bengaluru
# 8  Contractual Hiring For Top MNC || Business Dat...  Bangalore/Bengaluru
# 9            Master Data Management Business Analyst  Bangalore/Bengaluru
#
#                          Company Name Experience
# 0                             Cargill    3-5 Yrs
# 1                           MeritTrac   9-14 Yrs
# ...

# %% [markdown]
# # Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
# Connecting to webdriver (need to enter chromedriver.exe manually)

driver = webdriver.Chrome(r'C:\FLIP ROBO\Crome Driver\chromedriver.exe')

# opening url
url = 'https://www.naukri.com/'
driver.get(url)

# %%
# Maximizing the window

driver.maximize_window()

# %%
# inserting required fileds for the result

search_job = driver.find_element(By.CLASS_NAME , "suggestor-input")
search_job.send_keys("Data Scientist")
search_loc = driver.find_element (By.XPATH, '/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
search_loc.send_keys ('Bangalore')
search_button = driver.find_element (By.CLASS_NAME, "qsbSubmit")
search_button.click()

# %%
# Collecting data using XPATH for columns

job_title = []

title_tag = driver.find_elements (By.XPATH, '//a[@class="title fw500 ellipsis"]')
for i in title_tag[0:10]:
    job_title.append(i.text)

job_location = []

title_tag = driver.find_elements (By.XPATH, '//span[@class="ellipsis fleft fs12 lh16 locWdth"]')
for i in title_tag[0:10]:
    job_location.append(i.text)

company_name = []

title_tag = driver.find_elements (By.XPATH, '//a[@class="subTitle ellipsis fleft"]')
for i in title_tag[0:10]:
    company_name.append(i.text)

# %%
# checking length of each column
print (len (job_title), len(job_location), len(company_name))
# Out:
# 10 10 10

# %%
# Creating DataFrame to view 10 jobs data with available information

df = pd.DataFrame ({'Job Title': job_title, 'Job Location': job_location, 'Company Name': company_name})
df
# Out:
#                                         Job Title  \
# 0                Analystics & Modeling Specialist
# 1                Assistant Manager - Data Science
# 2                           Senior Data Scientist
# 3                      Program Manager, Analytics
# 4  Data Scientist - Looking For Immediate Joiners
# 5                                  Data Scientist
# 6                           Senior Data Scientist
# 7                             Data Scientist - II
# 8                               Lead ML Scientist
# 9                           Senior Data Scientist
#
#                                         Job Location             Company Name
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...                Accenture
# 1         Hybrid - Bangalore/Bengaluru, Mumbai, Pune               Citiustech
# 2        Hybrid - Bangalore/Bengaluru, Pune, Chennai                    Wipro
# 3                                Bangalore/Bengaluru                     Uber
# ...

# %% [markdown]
# # Q3: In this question you have to scrape data using the filters available on the webpage:
# You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company name, experience required.
# The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs
# The task will be done as shown in the below steps:
# 1. first get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
# 3. Then click the search button.
# 4. Then apply the location filter and salary filter by checking the respective boxes
# 5. Then scrape the data for the first 10 jobs results you get.
# 6. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
# Connecting to webdriver (need to enter chromedriver.exe manually)

driver = webdriver.Chrome(r'C:\FLIP ROBO\Crome Driver\chromedriver.exe')

# Getting URL

url = 'https://www.naukri.com/'
driver.get(url)

# %%
# inserting required fileds for the result

search_job = driver.find_element(By.CLASS_NAME , "suggestor-input")

search_job.send_keys("Data Scientist")

search_button = driver.find_element (By.CLASS_NAME, "qsbSubmit")

search_button.click()

# %%
# Selcting place in filter using xpath

loc_filter=driver.find_elements(By.XPATH, '//span[@class="ellipsis fleft"]')

for i in loc_filter :
    if (i.text=='Delhi / NCR'):
        i.click()
        break

# %%
# Selecting salary filter using Xpath

salary_filter = driver.find_elements (By.XPATH, '//span[@class="ellipsis fleft"]')

for i in salary_filter:
    if (i.text == '3-6 Lakhs'):
        i.click()
        break

# %%
# Collecting data using XPATH for columns

job_title = []

title_tag = driver.find_elements(By.XPATH, '//a[@class="title fw500 ellipsis"]')
for i in title_tag[0:10]:
    job_title.append(i.text)
len(job_title)
# Out:
# 10

# %%
# Collecting data using XPATH for columns

job_location = []

title_tag = driver.find_elements (By.XPATH, '//span[@class="ellipsis fleft fs12 lh16 locWdth"]')
for i in title_tag[0:10]:
    job_location.append(i.text)
len(job_location)
# Out:
# 10

# %%
# Collecting data using XPATH for columns

company_name = []

title_tag = driver.find_elements (By.XPATH, '//a[@class="subTitle ellipsis fleft"]')
for i in title_tag[0:10]:
    company_name.append(i.text)
len(company_name)
# Out:
# 10

# %%
# Collecting data using XPATH for columns


experience = []

title_tag = driver.find_elements (By.XPATH, '//span[@class="ellipsis fleft fs12 lh16 expwdth"]')
for i in title_tag[0:10]:
    experience.append(i.text)
len(experience)
# Out:
# 10

# %%
# Making table using DataFrame for first 10 job and other related columns.

df = pd.DataFrame ({'Job Title': job_title, 'Job Location': job_location, 'Company Name': company_name, 'Experience': experience})
df
# Out:
#                                            Job Title  \
# 0                                     Data Scientist
# 1                    DigitalBCG GAMMA Data Scientist
# 2   Urgent hiring For Data Scientist (PHD Must Have)
# 3  Manager - Data Science - Banking&Financial Ser...
# 4                Data Scientist / Sr. Data Scientist
# 5                                     Data Scientist
# 6                                     Data Scientist
# 7                                     Data Scientist
# 8                             Data scientist- Python
# 9                                     Data Scientist
#
#                                         Job Location  \
# 0  Noida, Hyderabad/Secunderabad, Chennai, Bangal...
# 1                     New Delhi, Bangalore/Bengaluru
# 2                            Temp. WFH - Noida, Pune
# 3                   Delhi / NCR, Bangalore/Bengaluru
# 4                                  Temp. WFH - Noida
# 5  Dehradun, Hyderabad/Secunderabad, Gurgaon/Guru...
# ...

# %% [markdown]
# # Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price
#
# To scrape the data you have to go through following steps:
# 1. Go to Flipkart webpage by url : https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and
# click the search icon
# 3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the
# required data as usual.
# 4. After scraping data from the first page, go to the “Next” Button at the bottom other page , then
# click on it.
# 5. Now scrape data from this page as usual
# 6. Repeat this until you get data for 100 sunglasses.
# Note: That all of the above steps have to be done by coding only and not manually

# %%
# Connecting to webdriver (need to enter chromedriver.exe manually)

driver = webdriver.Chrome(r'C:\FLIP ROBO\Crome Driver\chromedriver.exe')

# Getting URL
url = 'https://www.flipkart.com/'
driver.get(url)

# Need to remove pop up window, due to this unable to search data on website

remove_pop = driver.find_element(By.CLASS_NAME, '_2doB4z')
remove_pop.click()

# %%
# Maximizing the screen

maximize = driver.maximize_window()

# %%
# drafting code to search sunglasses on website

search_item = driver.find_element (By.CLASS_NAME, '_3704LK')
search_item.send_keys ("Sunglasses")

# %%
# code to click on search button

search_button = driver.find_element (By.CLASS_NAME, 'L0Z3Pu')
search_button.click()

# %%
# Distributing all data column wise

brand = []
product_discription = []
price = []
offer = []



for i in range (3):
    brand_new = driver.find_elements(By.XPATH, '//div[@class="_2WkVRV"]')
    for i in brand_new:
        brand.append(i.text)

    product_discritpion_new = driver.find_elements (By.XPATH, "//a[@class='IRpwTa']")
    for i in product_discritpion_new:
        product_discription.append(i.text)


    price_new = driver.find_elements (By.XPATH, "//div[@class='_30jeq3']")
    for i in price_new:
        price.append(i.text)
    

    offer_new = driver.find_elements (By.XPATH, "//div[@class='_3Ay6Sb']")
    for i in offer_new:
        offer.append(i.text)

    
time.sleep(10)        
   
next_btn = driver.find_element(By.XPATH, "//a[@class='_1LKTO3']")   
next_btn.click()

# This will collect data from other pages also

# %%
# Checking length of all pciked columns from different pages

print(len(brand),len(product_discription),len(price), len (offer))
# Out:
# 120 120 120 120

# %%
# Creating table using DataFrame for 100 sunglasses

df = pd.DataFrame ({'Brand Name': brand, 'Product Description': product_discription, 'Price': price, 'Discount':offer})
df.head (100)
# Out:
#         Brand Name                                Product Description Price  \
# 0   ROZZETTA CRAFT              UV Protection Aviator Sunglasses (62)  ₹616
# 1     Singco India  Gradient, Toughened Glass Lens, UV Protection ...  ₹575
# 2         Fastrack      UV Protection Wayfarer Sunglasses (Free Size)  ₹649
# 3         Fastrack   UV Protection Rectangular Sunglasses (Free Size)  ₹519
# 4           PIRASO          UV Protection Rectangular Sunglasses (52)  ₹209
# ..             ...                                                ...   ...
# 95          SUNBEE  UV Protection, Polarized Wayfarer Sunglasses (...  ₹283
# 96  ROZZETTA CRAFT  UV Protection, Gradient Retro Square Sunglasse...  ₹331
# 97    Singco India  Riding Glasses, UV Protection Clubmaster, Wayf...  ₹296
# 98       Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...  ₹176
# 99          PIRASO              UV Protection Aviator Sunglasses (54)  ₹251
#
#    Discount
# 0   75% off
# 1   80% off
# 2   35% off
# ...

# %% [markdown]
# # Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link:
#
# https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-poweradapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace.
#
# you have to scrape below attributes.These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100 reviews.
#
# Note: All the steps required during scraping should be done through code only and not manually.

# %%
driver = webdriver.Chrome(r'C:\FLIP ROBO\Crome Driver\chromedriver.exe')

# Getting URL (Taken different url as the one which was given is deleted)
url = 'https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART'
driver.get(url)

# Maximizing the screen

maximize = driver.maximize_window()

# %%
# Collecing data for various coulumns given

rating = []
review_sum = []
ful_review = []


#  collecing data from 10 pages

for i in range (10):
    rating_new = driver.find_elements(By.XPATH, '//div[@class="_3LWZlK _1BLPMq"]')
    for i in rating_new:
        rating.append(i.text)

    review_sum_new = driver.find_elements (By.XPATH, '//p[@class="_2-N8zT"]')
    for i in review_sum_new:
        review_sum.append(i.text)


    ful_review_new = driver.find_elements (By.XPATH, '//div[@class="t-ZTKy"]')
    for i in ful_review_new:
        ful_review.append(i.text)

# %%
# collecing data from next pages

time.sleep(10)
next_btn = driver.find_element(By.XPATH, '//a[@class="_1LKTO3"]')   
next_btn.click()

# %%
# Checking length of all columns

print (len(rating), len(review_sum), len(ful_review))
# Out:
# 100 100 100

# %%
# Making table using DataFrame for 100 reviews of flipkart

df = pd.DataFrame ({'Review Summary': review_sum, 'Rating':rating, 'Full Review':ful_review})
df
# Out:
#          Review Summary Rating  \
# 0        Simply awesome      5
# 1       Value-for-money      4
# 2      Perfect product!      5
# 3   Best in the market!      5
# 4    Highly recommended      5
# ..                  ...    ...
# 95    Worth every penny      5
# 96   Highly recommended      5
# 97     Perfect product!      5
# 98        Great product      5
# 99            Fabulous!      5
#
#                                           Full Review
# 0   Really satisfied with the Product I received.....
# 1   I'm Really happy with the product\nDelivery wa...
# 2   Amazing phone with great cameras and better ba...
# 3   Great iPhone very snappy experience as apple k...
# 4   It's my first time to use iOS phone and I am l...
# ..                                                ...
# 95  Previously I was using one plus 3t it was a gr...
# 96  What a camera .....just awesome ..you can feel...
# 97  Value for money\n5 star rating\nExcellent came...
# ...

# %% [markdown]
# # Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.
# You have to scrape 4 attributes of each sneaker:
# 1. Brand
# 2. Product Description
# 3. Price

# %%
# Connecting to webdriver (need to enter chromedriver.exe manually)

driver = webdriver.Chrome(r'C:\FLIP ROBO\Crome Driver\chromedriver.exe')

# Getting URL
url = 'https://www.flipkart.com/'
driver.get(url)

# Need to remove login pop up window

remove_pop = driver.find_element(By.CLASS_NAME, '_2doB4z')
remove_pop.click()

# %%
# Maximizing the screen

maximize = driver.maximize_window()

# %%
# Code to search sneakers on webiste

search_item = driver.find_element (By.CLASS_NAME, '_3704LK')
search_item.send_keys ("sneakers")

# %%
# Searching the result 

search_button = driver.find_element (By.CLASS_NAME, 'L0Z3Pu')
search_button.click()

# %%
# Collecing data of below these columns

brand = []
product_discription = []
price = []
offer = []


# Taking data from first 3 pages

for i in range (3):
    brand_new = driver.find_elements(By.XPATH, '//div[@class="_2WkVRV"]')
    for i in brand_new:
        brand.append(i.text)

    product_discritpion_new = driver.find_elements (By.XPATH, '//a[@class="IRpwTa"]')
    for i in product_discritpion_new:
        product_discription.append(i.text)


    price_new = driver.find_elements (By.XPATH, "//div[@class='_30jeq3']")
    for i in price_new:
        price.append(i.text)
    

    offer_new = driver.find_elements (By.XPATH, "//div[@class='_3Ay6Sb']")
    for i in offer_new:
        offer.append(i.text)

# Need to also collect data from next pages   
time.sleep(3)        
   
next_btn = driver.find_element(By.XPATH, "//a[@class='_1LKTO3']")   
next_btn.click()

# %%
# Creating table using DataFrame for top 100 sneakers
df = pd.DataFrame ({'Brand Name': brand[0:100], 'Product Description': product_discription[0:100], 'Price': price[0:100], 'Discount':offer[0:100]})
df
# Out:
#    Brand Name                                Product Description   Price  \
# 0       Zixer  Sneakers Dancing Shoes/Street Dancing Shoe For...    ₹565
# 1      Kraasa                                   Sneakers For Men    ₹499
# 2      RINDAS  Perfect Stylish Casual Shoes For Girls & Women...    ₹298
# 3    ASTEROID  Original Luxury Branded Fashionable Men's Casu...    ₹499
# 4        aadi  Mesh | Ultralightweight | Comfortable | Breath...    ₹499
# ..        ...                                                ...     ...
# 95     ACTION                Court Star Vulc FS Sneakers For Men    ₹449
# 96      asian      Stylish Casual Sports Shoe Sneakers For Women    ₹599
# 97     JUDDee                            SM-671 Sneakers For Men    ₹599
# 98   KWIK FIT                                 Sneakers For Women    ₹399
# 99     DUCATI             White Sneaker For Men Sneakers For Men  ₹1,299
#
#    Discount
# 0   62% off
# 1   50% off
# 2   70% off
# 3   50% off
# 4   75% off
# ...

# %% [markdown]
# # Q7: Go to the link - https://www.myntra.com/shoes Set second Price filter and Color filter to “Black”,
#
# And then scrape First 100 shoes data you get. The data should include “Brand” of the shoes , Short Shoe description, price of the shoe.
#
# Note: Applying the filter and scraping the data, everything should be done through code only and there
# should not be any manual step.
#  : In Case, Inspect click don’t works, Please use ctrl+shift+c to inspect the element.

# %%
driver = webdriver.Chrome(r'C:\FLIP ROBO\Crome Driver\chromedriver.exe')

# Getting URL (Taken different url as the one which was given is deleted)
url = 'https://www.myntra.com/shoes'
driver.get(url)

# %%
# Maximizing the screen

maximize = driver.maximize_window()

# %%
# Getting price filter

price_filter = driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label")
price_filter.click()
time.sleep(3)

# %%
# getting color filter to sort our data

color_filter = driver.find_element(By.XPATH, "/html/body/div[2]/div/main/div[3]/div[1]/section/div/div[6]/ul/li[1]")
color_filter.click()
time.sleep(3)

# %%
# getting data of all columns

brand = []
description = []
price = []

for i in range (2):
    brand_new = driver.find_elements(By.XPATH, '//h3[@class="product-brand"]')
    for i in brand_new:
        brand.append(i.text)

    description_new = driver.find_elements (By.XPATH, '//h4[@class="product-product"]')
    for i in description_new:
        description.append(i.text)
        
        
    price_new = driver.find_elements (By.XPATH, '//div[@class="product-price"]')
    for i in price_new:
        price.append(i.text.split('Rs.')[1])
price = [f'Rs.{n}' for n in price] - #Added Rs symbol to price

# %%
# Getting data of all columns from other page

time.sleep(3)

next_page = driver.find_element(By.XPATH, '/html/body/div[2]/div/main/div[3]/div[2]/div/div[2]/section/div[2]/ul/li[12]')
next_page.click()

# %%
# Checking length of column
print (len(brand), len(description), len (price))
# Out:
# 100 100 100

# %%
# Creating a table using DataFrame for shoes

df = pd.DataFrame ({'Brand':brand, 'Description':description, 'Price':price})
df
# Out:
#            Brand                     Description      Price
# 0         ADIDAS  Men Ultraboost 5.0 DNA Running  Rs. 11899
# 1           Nike         JORDAN MAX AURA 4 Shoes  Rs. 10165
# 2   UNDER ARMOUR  Men HOVR SonicSE Running Shoes   Rs. 9999
# 3           Puma    Eternity Nitro Running Shoes  Rs. 12999
# 4           Nike  AIR ZOOM G.T. Basketball Shoes  Rs. 13595
# ..           ...                             ...        ...
# 95          Nike  Men JORDAN LOW Basketball Shoe  Rs. 12795
# 96          TOMS  Men Alpargata Slip-On Sneakers   Rs. 7999
# 97         Ruosh             Men Leather Loafers   Rs. 8990
# 98          Geox             Leather Block Pumps  Rs. 10616
# 99        ADIDAS       Men Adistar Running Shoes  Rs. 12999
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q8: Go to webpage https://www.amazon.in/
#
#
# Enter “Laptop” in the search field and then click the search icon.
# Then set CPU Type filter to “Intel Core i7”:
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributesfor each laptop:
# 1. Title
# 2. Ratings
# 3. Price
#
# Note: All the steps required during scraping should be done through code only and not manually.

# %%
# Connecting to webdriver (need to enter chromedriver.exe manually)

driver = webdriver.Chrome(r'C:\FLIP ROBO\Crome Driver\chromedriver.exe')

# Getting URL
url = 'https://www.amazon.in/'
driver.get(url)

# %%
# Maximizing the screen

maximize = driver.maximize_window()

# %%
# Code to search item on website

search_item = driver.find_element (By.XPATH, '/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
search_item.send_keys ('Laptop')

# %%
# code to search item on website

srbt = driver.find_element (By.XPATH, '/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
srbt.click()

# %%
# Extracting and assing data to various columns

Rating = []
Title = []
Price = []

ratng = driver.find_elements (By.XPATH, "//div[@class='a-row a-size-small']/span")

for i in ratng:
    Rating.append(i.get_attribute('aria-label'))
    

for i in range(0,len(Rating))[0:20]:
    if i == 0 or i/2 == i//2:
        Rating.append (Rating [i][0:3])
del Rating [1::2]
del Rating [10::1]


title = driver.find_elements (By.XPATH, '//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
for i in title[0:10]:
    Title.append(i.text)


price = driver.find_elements (By.XPATH, '//span[@class="a-price-whole"]')
for i in price[0:10]:
    Price.append(i.text)

# %%
# Creating a table using DataFrame for laptops

df = pd.DataFrame ({'Title': Title, 'Ratings':Rating, 'Price':Price})
df
# Out:
#                                                Title             Ratings  \
# 0  Acer Extensa 15 Lightweight Laptop 11th Gen In...  3.9 out of 5 stars
# 1  Acer Aspire 3 AMD 3020e Dual core Processor (4...  3.2 out of 5 stars
# 2  Lenovo IdeaPad Slim 3 Intel Celeron N4020 4th ...  3.8 out of 5 stars
# 3  (Renewed) Dell Latitude E5470 Intel Core i5 6t...  3.7 out of 5 stars
# 4  ASUS VivoBook 15 (2021), 15.6-inch (39.62 cm) ...  3.9 out of 5 stars
# 5  HP 15s-Ryzen 3 3250U 8GB SDRAM/256GB SSD 15.6i...  3.9 out of 5 stars
# 6  ASUS Vivobook 15, 15.6" (39.62 cm) FHD, AMD Du...  2.7 out of 5 stars
# 7  Lenovo IdeaPad Slim 1 Intel Celeron N4020 11.6...  3.9 out of 5 stars
# 8  Acer Extensa 15 Lightweight Laptop 11th Gen In...  3.8 out of 5 stars
# 9  Dell New Windows 11 Inspiron 3525 Laptop, Inte...  3.9 out of 5 stars
#
#     Price
# 0  31,918
# 1  23,380
# 2  28,129
# 3  19,599
# 4  25,990
# 5  76,842
# 6  29,740
# 7  32,990
# 8  25,000
# 9  31,918

# %% [markdown]
# # Q9: Write a python program to scrape data for Top 1000 Quotes of All Time.
#  The above task will be done in following steps:
#  1.First get the webpage https://www.azquotes.com/
#  2. Click on Top Quotes
#  3. Than scrap a) Quote b) Author c) Type Of Quote

# %%
driver = webdriver.Chrome(r'C:\FLIP ROBO\Crome Driver\chromedriver.exe')

# Getting URL (Taken different url as the one which was given is deleted)
url = 'https://www.azquotes.com/'
driver.get(url)

# %%
# Maximing the screen

maximize = driver.maximize_window()

# %%
# Getting top qutoes page using below code

top_quotes = driver.find_element (By.XPATH, '/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a')
top_quotes.click()

# %%
# Gattering data from page and assingning data to below columns

Quote = []
Author = []
Type = []

for i in range (10):
    quote = driver.find_elements (By.XPATH, '//a[@class="title"]')
    for i in quote:
        Quote.append (i.text)
    
    author = driver.find_elements (By.XPATH, '//div[@class="author"]')
    for i in author:
        Author.append (i.text)
    
    typ = driver.find_elements (By.XPATH, '//div[@class="tags"]')
    for i in typ:
        Type.append (i.text)

# Getting data from other pages
time.sleep(3)
next_page = driver.find_element(By.XPATH, '/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[4]/li[12]/a')
next_page.click()

# %%
# Creating table using DataFrame for 1000 quotes

df = pd.DataFrame({'Name of Author': Author, 'Type of Quote': Type, 'Quote': Quote})
df
# Out:
#            Name of Author                             Type of Quote  \
# 0          Michael Porter  Essence, Deep Thought, Transcendentalism
# 1              Golda Meir                 Inspiration, Past, Trying
# 2      Theodore Roosevelt                       Country, Peace, War
# 3          Nelson Mandela        Inspirational, Motivational, Death
# 4            Erma Bombeck              4th Of July, Food, Patriotic
# ..                    ...                                       ...
# 995    Hunter S. Thompson                    Music, Sports, Hunting
# 996       Corrie Ten Boom             Trust, Encouraging, Uplifting
# 997         Mother Teresa                      Success, God, Mother
# 998            Dalai Lama              Inspirational, Funny, Change
# 999  Norman Vincent Peale       Inspirational, Motivational, Change
#
#                                                  Quote
# 0    The essence of strategy is choosing what not t...
# ...

# %% [markdown]
# # Q10: Write s python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead, Term of office, Remarks) from https://www.jagranjosh.com/.
# This task will be done in following steps:
# 1. First get the webpage https://www.jagranjosh.com/
# 2. Then You have to click on the GK option
# 3. Then click on the List of all Prime Ministers of India
# 4. Then scrap the mentioned data and make the DataFrame.

# %%
driver = webdriver.Chrome(r'C:\FLIP ROBO\Crome Driver\chromedriver.exe')

# Getting URL (Taken different url as the one which was given is deleted)
url = 'https://www.jagranjosh.com/'
driver.get(url)

# %%
# Maximizing the screen

maximize = driver.maximize_window()

# %%
# Clicking on GK option using below code

GK_option = driver.find_element (By.XPATH, '/html/body/div[1]/div[1]/div/div[1]/div/div[6]/div/div[1]/header/div[3]/ul/li[9]/a')
GK_option.click()
time.sleep(2)

# %%
# clicking on pm list using below code

pm_option = driver.find_element (By.XPATH, '/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
pm_option.click ()
time.sleep (2)

# %%
# Converting table data to our Data frame

table = 'https://www.jagranjosh.com/general-knowledge/list-of-all-prime-ministers-of-india-1473165149-1'
df_table = pd.read_html(table)

# %%
# Finally geeting information and converting web table to DataFrame
df_table [0]  # taken [0] as there are 2 tables on the page
# Out:
#     S.N.                        Name     Born-Dead  \
# 0    1.0           Jawahar Lal Nehru   (1889–1964)
# 1    2.0   Gulzarilal Nanda (Acting)   (1898-1998)
# 2    3.0         Lal Bahadur Shastri   (1904–1966)
# 3    4.0  Gulzari Lal Nanda (Acting)   (1898-1998)
# 4    5.0               Indira Gandhi   (1917–1984)
# 5    6.0               Morarji Desai   (1896–1995)
# 6    7.0                Charan Singh   (1902–1987)
# 7    8.0               Indira Gandhi   (1917–1984)
# 8    9.0                Rajiv Gandhi   (1944–1991)
# 9   10.0                 V. P. Singh   (1931–2008)
# 10  11.0             Chandra Shekhar   (1927–2007)
# 11  12.0         P. V. Narasimha Rao   (1921–2004)
# 12  13.0        Atal Bihari Vajpayee  (1924- 2018)
# 13  14.0            H. D. Deve Gowda   (born 1933)
# 14  15.0          Inder Kumar Gujral   (1919–2012)
# 15  16.0        Atal Bihari Vajpayee   (1924-2018)
# 16  17.0              Manmohan Singh   (born 1932)
# ...

# %% [markdown]
# # Q11: Write s python program to display list of 50 Most expensive cars in the world (i.e. Company name, Model name and Price) from https://www.motor1.com/
#
# This task will be done in following steps:
# 1. First get the webpage https://www.motor1.com/
# 2. Then You have to click on the List option from Dropdown menu on left side.
# 3. Then click on 50 most expensive cars in the world..
# 4. Then scrap the mentioned data and make the

# %%
driver = webdriver.Chrome(r'C:\FLIP ROBO\Crome Driver\chromedriver.exe')

# Getting URL (Taken different url as the one which was given is deleted)
url = 'https://www.motor1.com/'
driver.get(url)

# %%
# Mazimizing the table

maximize = driver.maximize_window()

# %%
# Seleting drop_down list

drop_down = driver.find_element (By.XPATH, '/html/body/div[2]/div[2]/div/div/div[1]/div')
drop_down.click()
time.sleep(2)

# %%
# Selecing list option

list_opt = driver.find_element (By.XPATH, '/html/body/div[3]/div[1]/div[3]/ul/li[4]/a')
list_opt.click()

# %%
# Selecing Cars using below code

top_cars = driver.find_element (By.XPATH, '/html/body/div[2]/div[9]/div[1]/div[1]/div/div/div[1]/div/div[1]/h3/a')
top_cars.click()

# %%
# Cars company name is unavailable on the site provided so taken name and price of cars

name = []

m_name = driver.find_elements (By.XPATH, '//h3[@class="subheader"]')
for i in m_name[0:50]:
    name.append(i.text)
    
price = []
n_price = driver.find_elements (By.TAG_NAME, 'strong')
for i in n_price:
    price.append(i.text)
del price [4]

# %%
# Creating table using DataFrame for car name and price, compnay name is unavailable.
df = pd.DataFrame({'Car Name': name, 'Price':price})
df
# Out:
#                            Car Name                        Price
# 0                         Drako GTE          Price: $1.2 Million
# 1                     De Tomaso P72          Price: $1.3 Million
# 2                 Ferrari LaFerrari          Price: $1.4 Million
# 3                     Pagani Huayra          Price: $1.4 Million
# 4                      McLaren Elva          Price: $1.7 Million
# 5                       Czinger 21C          Price: $1.7 Million
# 6                     Ferrari Monza          Price: $1.7 Million
# 7                Gordon Murray T.33          Price: $1.7 Million
# 8                 Koenigsegg Gemera          Price: $1.7 Million
# 9                       Zenvo TSR-S          Price: $1.7 Million
# 10               Hennessey Venom F5          Price: $1.8 Million
# 11                  Bentley Bacalar          Price: $1.9 Million
# 12    Hispano Suiza Carmen Boulogne          Price: $1.9 Million
# ...
